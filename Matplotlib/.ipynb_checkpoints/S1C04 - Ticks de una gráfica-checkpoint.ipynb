# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import math as m

from matplotlib.ticker import MultipleLocator, AutoMinorLocator, FuncFormatter
from matplotlib.patches import Circle

# %% [markdown]
# ## Anatomia de una Grafica
# #### Figura, axes y axis

# %%
# Reiniciamos mpl y sembramos la semilla para los numeros aleatorios
mpl.rcParams.update(mpl.rcParamsDefault)
np.random.seed(123)

# %%
x = np.linspace(0.5, 3.5, 100) # secuencia
y1 = 3 + np.cos(x)
y1
# Out:
# array([3.87758256, 3.86265384, 3.84693302, 3.83043455, 3.81317357,
#        3.79516594, 3.77642817, 3.75697749, 3.73683175, 3.71600945,
#        3.69452971, 3.67241224, 3.64967737, 3.62634596, 3.60243944,
#        3.57797975, 3.55298936, 3.52749122, 3.50150873, 3.47506575,
#        3.44818657, 3.42089586, 3.39321868, 3.36518045, 3.3368069 ,
#        3.30812411, 3.27915839, 3.24993634, 3.2204848 , 3.19083082,
#        3.16100161, 3.13102457, 3.10092722, 3.0707372 , 3.04048223,
#        3.01019009, 2.97988859, 2.94960556, 2.9193688 , 2.88920608,
#        2.85914509, 2.82921343, 2.79943859, 2.7698479 , 2.74046854,
#        2.71132748, 2.68245149, 2.65386707, 2.62560046, 2.59767764,
#        2.57012422, 2.54296552, 2.51622647, 2.48993163, 2.46410513,
#        2.43877069, 2.41395157, 2.38967056, 2.36594997, 2.34281155,
#        2.32027657, 2.29836572, 2.27709911, 2.25649627, 2.23657611,
#        2.21735693, 2.19885638, 2.18109145, 2.16407843, 2.14783297,
#        2.13236996, 2.11770362, 2.1038474 , 2.09081404, 2.07861549,
#        2.06726296, 2.05676687, 2.04713686, 2.03838178, 2.03050965,
#        2.02352772, 2.01744238, 2.01225924, 2.00798304, 2.00461771,
#        2.00216635, 2.0006312 , 2.00001367, 2.00031434, 2.00153292,
#        2.00366829, 2.0067185 , 2.01068075, 2.01555139, 2.02132596,
#        2.02799914, 2.03556483, 2.04401606, 2.05334507, 2.06354331])

# %%
y2 = 1 + np.cos(1 + x/0.75)/2
y2
# Out:
# array([0.95213823, 0.93207351, 0.91211966, 0.89230926, 0.87267464,
#        0.85324785, 0.83406059, 0.81514419, 0.79652953, 0.77824698,
#        0.7603264 , 0.74279702, 0.72568747, 0.70902567, 0.69283881,
#        0.67715332, 0.66199481, 0.64738801, 0.63335676, 0.61992397,
#        0.60711157, 0.59494046, 0.58343052, 0.57260053, 0.56246817,
#        0.55304998, 0.54436133, 0.5364164 , 0.52922816, 0.52280835,
#        0.51716744, 0.51231464, 0.50825787, 0.50500375, 0.5025576 ,
#        0.50092341, 0.50010384, 0.50010023, 0.50091259, 0.5025396 ,
#        0.50497859, 0.50822559, 0.51227529, 0.51712109, 0.52275508,
#        0.52916805, 0.53634955, 0.54428785, 0.55296999, 0.5623818 ,
#        0.57250792, 0.58333182, 0.59483583, 0.60700118, 0.61980801,
#        0.63323541, 0.64726147, 0.66186328, 0.67701703, 0.69269797,
#        0.70888051, 0.72553824, 0.74264395, 0.76016974, 0.778087  ,
#        0.79636648, 0.81497834, 0.83389221, 0.85307721, 0.87250202,
#        0.89213494, 0.91194393, 0.93189665, 0.95196054, 0.97210283,
#        0.99229066, 1.01249108, 1.03267111, 1.0527978 , 1.07283832,
#        1.09275995, 1.11253017, 1.13211671, 1.1514876 , 1.17061122,
#        1.18945636, 1.20799225, 1.22618865, 1.24401585, 1.26144475,
#        1.2784469 , 1.29499456, 1.3110607 , 1.32661912, 1.3416444 ,
#        1.35611203, 1.36999839, 1.38328081, 1.39593762, 1.40794816])

# %%
y3 = np.random.uniform(y1, y2, len(x)) # distrubición uniforme
y3
# Out:
# array([1.84010073, 3.02409953, 3.18116635, 2.21060269, 1.69757583,
#        2.55042139, 0.89065939, 1.74232256, 2.32274661, 2.56406132,
#        2.68757564, 1.53657712, 2.36729655, 3.45224642, 2.44428962,
#        1.43718317, 3.02540676, 3.02217205, 1.97693861, 1.95662259,
#        1.64580587, 1.0204395 , 1.35765269, 1.65884847, 1.33250425,
#        2.41834836, 2.28973984, 2.63053951, 2.43002493, 1.50737234,
#        2.91749142, 1.995287  , 1.98384254, 1.80407283, 1.95975705,
#        2.22664341, 1.92262912, 0.76124404, 0.63595914, 1.69148931,
#        1.39025595, 2.56086454, 2.07375488, 1.83535777, 0.81924306,
#        2.16479395, 1.64581072, 0.57475063, 1.54889977, 1.35025596,
#        2.32915443, 0.92364024, 1.35751239, 1.46360648, 1.83194678,
#        1.88966987, 1.67720256, 1.21251414, 0.88736207, 1.50055672,
#        1.24174698, 1.37678861, 1.31821271, 1.24694115, 1.00802884,
#        2.09913765, 1.14201247, 1.85282429, 1.90945189, 1.41776089,
#        2.01366395, 1.05021222, 1.3687425 , 1.26694879, 2.06076832,
#        1.42826516, 1.47532957, 1.88587775, 1.88751793, 1.36442096,
#        1.7268302 , 1.39127001, 1.52432296, 1.67484864, 1.23305121,
#        1.31813273, 1.71734397, 1.96628151, 1.7698187 , 1.70684041,
#        1.49241707, 1.29829804, 1.76167557, 1.49020759, 1.61815455,
#        1.56325362, 1.93497947, 1.78046443, 1.89500461, 1.83837521])

# %% [markdown]
# ## Figura (contenedor)

# %%
fig, ax = plt.subplots(figsize=(8,8)); # esto crea figura contenedor y axes, con 8 de ancho y 8 de alto

# %%
fig

# %%
ax

# %%
ax.xaxis.set_major_locator(MultipleLocator(1.0000)) # los Ticks mayores seran multiplos de 1

# %%
fig

# %%
ax.xaxis.set_minor_locator(AutoMinorLocator(4)) # 4 ticks menores equidistantes

# %%
fig

# %% [markdown]
# Para el eje y seria:

# %%
ax.yaxis.set_major_locator(MultipleLocator(1.000))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
fig

# %% [markdown]
# ### Text

# %%
#ax.text(.5,.5, 'Hola mundo') # coordenadaX, coordenadaY, texto
#fig

# %%
# ax.text(.5,.5, 'Hola mundo', ha='center') # Centrado vertical y horizontal
# fig

# %%
# ax.text(0.2,0.2, 'Hola mundo', ha='center', weight='bold', color='blue') # tambien se puede usando RGB, (0,0,0)
# ax.text(0.3,0.3, 'Hola mundo', ha='center', weight='bold', color=(123/255, 100/255, 180/255), backgroundcolor='yellow') # usando RGB y un background

# para los colores se usan numeros entre 0 y 1, enteonces para usar el rgb se debe usar (123/255, 100/255, 180/255)
# fig

# %%
 ax.set(xlim = [0,4], ylim = [0,4])

ax.text(0.5, 0.3, 'Axes', ha='center', weight='bold', color='blue', backgroundcolor='white', va = 'top')
#va = alineación vertical
fig

# %% [markdown]
# ###  Circulos

# %%
# circulo = Circle((.5, .5, ), 0.15, linewidth=1, edgecolor='black', facecolor=(0,0,0,0.02)) # CoordenadaX, CoordenadaY, radio, grosor linea, bordecirculo
# facecolor(0,0,0,0.02) para crear el relleno transparente, se usa el 4 parametro en el RGB, el cual es la trasnsparencia, entre mas cercado a cero, mas transparente
# ax.add_artist(circulo)
# fig

# %% [markdown]
# ## 6. Funciones y métodos para una gráfica

# %%
def addCircle(x, y):
    c1 = Circle((x, y), 0.15, linewidth=1, edgecolor='black', facecolor=(0,0,0,0.02), clip_on=False)
    ax.add_artist(c1)

# %%
def addText(x, y, text):
    ax.text(x, y, text, ha='center', weight='bold', color='blue', backgroundcolor='white', va = 'top')

# %%
addCircle(0.5, 0.5)
addText(0.5, 0.3, 'Axis')
fig

# %%
ax.tick_params(which='major', width= 1.0, length=10) # se notas mas los mayores y menores
ax.tick_params(which='minor', width= 1.0, length=10)
fig

# %% [markdown]
# ### Colocar valores a los ticks menores

# %%
def tickMenor(x, pos):
    if not x % 1.0:
        return ""
    else:
        return "%.2f"%x
    
ax.xaxis.set_minor_formatter(FuncFormatter(tickMenor)) # recibe una función
fig

# %%
### Agregar una malla a toda la grafica

# %%
ax.grid(linestyle="-.", linewidth=0.5, color='grey')
fig

# %% [markdown]
# ### Lineas

# %%
ax.plot(x, y1, color=(0, 104/255, 139/255), lw = 2, label="Señal Azul")
ax.plot(x, y2, c = (0,100/255,0),lw = 2, label="Señal Verde")
fig

# %% [markdown]
# ### Minor Tick

# %%
addCircle(0.5, -0.1)
addText(0.5, -0.32, 'Minor tick label')
addCircle(0.0, 3.5)
addText(0.5, -0.32, 'Minor tick')
fig

# %% [markdown]
# ### Major Tick

# %%
addCircle(-0.03, 4)
addText(0.03,3.8, 'Major tick')
addCircle(-0.15, 3)
addText(-0.5, 2.8, 'Majo tick')
fig

# %% [markdown]
# ### Lineas

# %%
addCircle(1.75, 2.8)
addText(1.75, 2.55, 'Line\n(line plot)')
addCircle(1.2, 0.6)
addText(1.2, 0.4, 'Line\n(line plot)')
fig

# %% [markdown]
# ## S1C10 Gráfico de Dispersión

# %%
ax.plot(x, y3, lw = 0, marker='o', markerfacecolor= 'w', markeredgecolor = (139/255,105/255,20/255))

#Dispersión
addCircle(3.2, 1.75)
addText(3.2, 1.55, 'Markets\n(scatter plot)')
fig

# %% [markdown]
#  ## S1C11 Títulos y etiquetas en una gráfica

# %%
ax.set_title('Anatomia de una figura', fontsize=20)
addCircle(1.60,4.13)
addText(1.60, 3.93, 'Title')
ax.set_xlabel('Eje de la X')
ax.set_ylabel('Eje de la Y')
fig

# %% [markdown]
# ### Ejes

# %%
# eje x
addCircle(1.8, -0.27)
addText(1.8, -0.5, 'X axis label')

# eje y
addCircle(-0.27, 1.8)
addText(-0.27, 1.6, 'Y axis label')

fig

# %% [markdown]
# ### S1C12 Leyenda y mas anotaciones en la gráfica
# #### Figura

# %%
addCircle(-0.3, 0.65)
addText(-0.3, 0.45, 'Figure')
fig

# %% [markdown]
# ### Convenciones

# %%
ax.legend()
fig

# %%
ax.annotate('Legend', xy=(3.6, 3.65), xytext=(3.5, 3.35), color= 'blue', weight='bold', ha='center'
           , arrowprops={'arrowstyle':'->', 'color':'blue', 'connectionstyle' : 'arc3'}
           )
# xy, donde va la anotación, hacia donde va la flecha
# xytext, donde va la dirección del texto

ax.annotate('Spines', xytext=(3.3, 0.45), xy = (4.0,0.35), weight='bold', color='blue'
           , arrowprops={'arrowstyle':'->', 'color':'blue', 'connectionstyle' : 'arc3'}
           )
#segunda flecha, hacia abajo
ax.annotate('', xytext=(3.4, 0.45), xy = (3.25, 0), weight='bold', color='blue'
           , arrowprops={'arrowstyle':'->', 'color':'blue', 'connectionstyle' : 'arc3'}
           )

fig
